# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("property_listings.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("property_listings.csv")
#
# File c:\Users\Hemanth.L\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Hemanth.L\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Hemanth.L\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Hemanth.L\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\Hemanth.L\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'property_listings.csv'

# %%
df = pd.read_csv("../notebook/data/property_listings.csv")

# %%
print("🧾 Dataset Info:")
print(df.info())
# Out:
# 🧾 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18778 entries, 0 to 18777
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   zpid             18777 non-null  float64
#  1   price            18777 non-null  float64
#  2   homeStatus       18777 non-null  object
#  3   homeType         18777 non-null  object
#  4   datePosted       18750 non-null  object
#  5   streetAddress    18777 non-null  object
#  6   city             18777 non-null  object
#  7   state            18777 non-null  object
#  8   zipcode          18777 non-null  float64
#  9   county           18763 non-null  object
#  10  yearBuilt        18025 non-null  float64
#  11  livingArea       17669 non-null  float64
#  12  livingAreaUnits  17673 non-null  object
#  13  rentZestimate    13691 non-null  float64
#  14  bathrooms        18304 non-null  float64
#  15  bedrooms         18119 non-null  float64
#  16  pageViewCount    18776 non-null  float64
#  17  favoriteCount    18776 non-null  float64
#  18  propertyTaxRate  18776 non-null  float64
#  19  timeOnZillow     18459 non-null  object
#  20  dateSold         3686 non-null   object
#  21  url              18777 non-null  object
#  22  lastUpdated      18778 non-null  object
# dtypes: float64(11), object(12)
# memory usage: 3.3+ MB
# None

# %%
print("\n📊 Statistical Summary:")
print(df.describe(include='all'))
# Out:
# 📊 Statistical Summary:
#                 zpid         price homeStatus       homeType  datePosted  \
# count   1.877700e+04  1.877700e+04      18777          18777       18750
# unique           NaN           NaN          7              7         344
# top              NaN           NaN   For Sale  Single Family  2024-11-22
# freq             NaN           NaN      15003          11304        2531
# mean    2.631983e+08  6.730238e+05        NaN            NaN         NaN
# std     5.277399e+08  3.630882e+06        NaN            NaN         NaN
# min     1.069739e+06  0.000000e+00        NaN            NaN         NaN
# 25%     2.624716e+07  2.525000e+05        NaN            NaN         NaN
# 50%     5.296319e+07  3.999990e+05        NaN            NaN         NaN
# 75%     3.219012e+08  6.900000e+05        NaN            NaN         NaN
# max     2.146974e+09  4.750000e+08        NaN            NaN         NaN
#
#                 streetAddress     city  state       zipcode         county  \
# count                   18777    18777  18777  18777.000000          18763
# unique                  18379      323     21           NaN             67
# top     (Undisclosed Address)  Houston     TX           NaN  Harris County
# freq                       39     1269   3288           NaN           1323
# mean                      NaN      NaN    NaN  51667.758428            NaN
# std                       NaN      NaN    NaN  28080.881461            NaN
# min                       NaN      NaN    NaN   2108.000000            NaN
# 25%                       NaN      NaN    NaN  30047.000000            NaN
# 50%                       NaN      NaN    NaN  44135.000000            NaN
# 75%                       NaN      NaN    NaN  78249.000000            NaN
# max                       NaN      NaN    NaN  98199.000000            NaN
#
#         ...  rentZestimate     bathrooms      bedrooms  pageViewCount  \
# count   ...   13691.000000  18304.000000  18119.000000   18776.000000
# unique  ...            NaN           NaN           NaN            NaN
# top     ...            NaN           NaN           NaN            NaN
# freq    ...            NaN           NaN           NaN            NaN
# mean    ...    2949.399240      4.736806      6.220211     203.498029
# std     ...    2943.427583    284.604419    381.164350     396.750776
# min     ...     673.000000      0.000000      0.000000       0.000000
# 25%     ...    1801.000000      2.000000      3.000000      50.000000
# 50%     ...    2338.000000      2.000000      3.000000     120.000000
# 75%     ...    3293.500000      3.000000      4.000000     235.000000
# max     ...  108970.000000  38451.000000  51268.000000   18880.000000
#
#         favoriteCount  propertyTaxRate  timeOnZillow    dateSold  \
# count    18776.000000     18776.000000         18459        3686
# unique            NaN              NaN           127          13
# top               NaN              NaN         1 day  2024-11-22
# freq              NaN              NaN          6258         863
# mean        12.473477         1.034852           NaN         NaN
# std         27.479579         0.491043           NaN         NaN
# min          0.000000         0.000000           NaN         NaN
# 25%          2.000000         0.670000           NaN         NaN
# 50%          6.000000         0.860000           NaN         NaN
# 75%         14.000000         1.470000           NaN         NaN
# max       1518.000000         2.000000           NaN         NaN
#
#                                                       url  \
# count                                               18777
# unique                                              18415
# top     https://www.zillow.com/homedetails/1089-Avon-A...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                            lastUpdated
# count                            18778
# unique                              20
# top     2024-11-23 15:13:45.862503 UTC
# freq                              2494
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
# [11 rows x 23 columns]

# %%
print("\n❗ Missing Values:")
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# ❗ Missing Values:
# dateSold           15092
# rentZestimate       5087
# livingArea          1109
# livingAreaUnits     1105
# yearBuilt            753
# bedrooms             659
# bathrooms            474
# timeOnZillow         319
# datePosted            28
# county                15
# propertyTaxRate        2
# favoriteCount          2
# pageViewCount          2
# url                    1
# zpid                   1
# price                  1
# zipcode                1
# state                  1
# city                   1
# streetAddress          1
# homeType               1
# homeStatus             1
# lastUpdated            0
# dtype: int64

# %%
columns = ['price', 'rentZestimate', 'bathrooms', 'bedrooms']
df[columns].hist(bins=30, figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
